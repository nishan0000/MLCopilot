# %%
import sys
sys.path.append("../PyFiles/")

# %%
# Library Imports
import pandas as pd
import os

# %%
# Package Imports
import configs as cf
from logger import App_Logger
from data_loader_train import Data_Loader
from project_gen import Create_Project

# %%
# Instantiate the logger object
logger_object = App_Logger()

# Create an instance of the Create_Project class
project_instance = Create_Project(logger_object)

# Call the initiate_project method on the instance
project_id = project_instance.initiate_project()
project_id
# Out:
# '20240310214949'

# %%
# Open a file for logging in append mode to prevent overwriting
file_object = open(os.path.join(cf.FILE_PATH, cf.output_files, project_id, 'Logs', 'Global_Logs.txt'), "a")

inp_file = r"C:\Users\mnsnn\Downloads\ThyroidDetection (1)\ThyroidDetection\code\Thyroid_Detection\Training_FileFromDB\InputFile.csv"
# Now, you can pass file_object to Data_Getter and it will remain open
data_getter = Data_Loader(file_object, logger_object, inp_file)
display(data_getter.load_data())

# Remember to close the file manually when you're done
# file_object.close()
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...
